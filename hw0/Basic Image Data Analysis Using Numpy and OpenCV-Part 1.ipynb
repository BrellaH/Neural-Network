# %% [markdown]
# HW0 Part 1
# Basic Image Data Analysis Using Numpy and OpenCV

# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline

pic = imageio.imread('demo_2.jpg')
plt.figure(figsize=(15,15))

plt.imshow(pic)

# %%
print('Type of the image: ',type(pic))
print()
print('Shape of the image : {}    #length, width, layers:RGB'.format(pic.shape)) 
print('Image size {}    #height x width x 3'.format(pic.size))
print('Image Height {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
print()
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Type of the image:  <class 'imageio.core.util.Array'>
#
# Shape of the image : (562, 960, 3)    #length, width, layers:RGB
# Image size 1618560    #height x width x 3
# Image Height 562
# Image Width 960
# Dimension of Image 3
#
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
print('Value of only R channel {}'.format(pic[100,50,0]))
print('Value of only B channel {}'.format(pic[100,50,1]))
print('Value of only G channel {}'.format(pic[100,50,2]))
# Out:
# Value of only R channel 109
# Value of only B channel 143
# Value of only G channel 46

# %%
plt.title('R channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[:,:,0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[:,:,1])
plt.show()

# %%
plt.title('B channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[:,:,2])
plt.show()

# %%
pic=imageio.imread('demo_2.jpg')
pic[50:150,:,0]=255
pic[150:200,:,0]=0
pic[50:450,220:270]=200
plt.figure(figsize=(10,10))
plt.imshow(pic)
plt.show()

# %%
import numpy as np
pic=imageio.imread('demo_2.jpg')
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(15,5))
for c,ax in zip(range(3),ax):
    # create zero matrix
    split_img=np.zeros(pic.shape,dtype="uint8")#'dtype' by default: 'numpy.float64'
    # assing each channel 
    split_img[:,:,c]=pic[:,:,c]
    # display each channel
    ax.imshow(split_img)

# %% [markdown]
# formula for converting to greyscale: y'=0.299R+0.587G+0.114B

# %%
pic=imageio.imread('demo_2.jpg')
gray=lambda rgb:np.dot(rgb[...,:3],[0.299,0.587,0.114])
gray=gray(pic)
plt.figure(figsize=(10,10))
plt.imshow(gray,cmap=plt.get_cmap(name='gray'))
plt.show()

# %%
pic = imageio.imread('demo_2.jpg')
gray = lambda rgb:np.dot(rgb[...,:3],[0.21,0.72,0.07])
gray = gray(pic)
plt.figure(figsize=(10,10))
plt.imshow(gray,cmap=plt.get_cmap(name='gray'))
plt.show()

# %%
print('Type of the image: ',type(gray))
print()
print('Shape of the image: {}'.format(gray.shape))
print('Image Height {}'.format(gray.shape[0]))
print('Image Width {}'.format(gray.shape[1]))
print('Dimension of Image {}'.format(gray.ndim))
print()
print('Image size {}'.format(gray.size))
print('Maximum RGB value in this image {}'.format(gray.max()))
print('Minimum RGB value in this image {}'.format(gray.min()))
print('Random indexes [X,Y] : {}'.format(gray[100,50]))
# Out:
# Type of the image:  <class 'imageio.core.util.Array'>
#
# Shape of the image: (562, 960)
# Image Height 562
# Image Width 960
# Dimension of Image 2
#
# Image size 539520
# Maximum RGB value in this image 254.99999999999997
# Minimum RGB value in this image 0.0
# Random indexes [X,Y] : 129.07
